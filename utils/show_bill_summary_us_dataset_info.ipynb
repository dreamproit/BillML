# %%
import pandas as pd
import json

from common.constants.billml import BillMLConstants

# edit this to change the dataset file
DATASET_FILE_NAME = 'bill_summary_us_11-10-2023_16-29-34.jsonl'

DATASET_PATH = (
    f'{BillMLConstants.BILLML_DATASETS_STORAGE_FILEPATH.value}/'
    f'{BillMLConstants.BILLML_BILL_SUMMARIES_US_DATASET_NAME.value}/'
    f'{DATASET_FILE_NAME}'
)
chunks = pd.read_json(path_or_buf=DATASET_PATH, lines=True, chunksize=10000)
dfs = []
for chunk in chunks:
  dfs.append(chunk)

df = pd.concat(dfs)

# %%
print('Dataset top rows:')
df.head(10)
# Out:
# Dataset top rows:
#                 id  congress bill_type  bill_number bill_version  \
# 0  108hconres408ih       108   hconres          408           ih
# 1  108hconres449ih       108   hconres          449           ih
# 2  108hconres510ih       108   hconres          510           ih
# 3  108hconres392ih       108   hconres          392           ih
# 4  108hconres482ih       108   hconres          482           ih
# 5  108hconres370ih       108   hconres          370           ih
# 6  108hconres411ih       108   hconres          411           ih
# 7  108hconres445ih       108   hconres          445           ih
# 8  108hconres478ih       108   hconres          478           ih
# 9  108hconres460ih       108   hconres          460           ih
#
#                                             sections  sections_length  \
# 0  [{'text': 'That Congress— (1) congratulates th...                2
# 1  [{'text': 'That Congress — (1) honors the life...                1
# 2  [{'text': 'That it is the sense of Congress th...                1
# 3  [{'text': 'That', 'id': 'HE65D4744627B47F1B2CC...                2
# 4  [{'text': 'That Congress— (1) recognizes and c...                1
# 5  [{'text': 'That it is the sense of Congress th...                1
# 6  [{'text': '', 'id': 'HF7F1B587F53E42FE9200B9AC...                2
# 7  [{'text': 'That the Congress— (1) recognizes t...                1
# 8  [{'text': 'That it is the sense of Congress th...                1
# 9  [{'text': 'That Congress— (1) strongly endorse...                1
#
#                                                 text  text_length  \
# 0  That Congress— (1) congratulates the Universit...          811
# 1  That Congress — (1) honors the life and accomp...          303
# 2  That it is the sense of Congress that the Unit...          529
# 3  That Congress calls for the adoption of a Sens...         4687
# 4  That Congress— (1) recognizes and celebrates t...         1261
# 5  That it is the sense of Congress that— (1) the...          860
# 6   That— (1) the Congress recognizes and honors ...          472
# 7  That the Congress— (1) recognizes the outstand...          489
# 8  That it is the sense of Congress that the Supr...          289
# 9  That Congress— (1) strongly endorses the princ...          525
#
#                                              summary  summary_length  \
# 0  (This measure has not been amended since it wa...             586
# 1  (This measure has not been amended since it wa...             328
# 2  Expresses the sense of Congress that the Unite...             154
# 3  Calls for the adoption of a Sensible, Multilat...             640
# 4  Recognizes and celebrates the abolition of sla...            1223
# 5  Expresses the sense of Congress that the Unite...             625
# 6  Expresses the sense of the Congress honoring t...             358
# 7  Recognizes the outstanding contribution of Nat...             357
# 8  Expresses the sense of Congress that the Supre...             267
# 9  (This measure has not been amended since it wa...             630
#
#                                                title
# 0  Congratulating the University of Denver men's ...
# 1  Honoring the life and accomplishments of Ray C...
# 2  Expressing the sense of the Congress on the im...
# 3  Calling for the adoption of a Sensible, Multil...
# 4  Recognizing and celebrating the abolition of s...
# 5  Expressing the sense of Congress that the Unit...
# 6  To express the sense of the Congress regarding...
# 7  Recognizing the invaluable contribution of Nat...
# 8  Expressing the sense of Congress that the Supr...
# 9  Regarding the security of Israel and the princ...

# %%
print('Dataset bottom rows:')
df.tail(10)
# Out:
# Dataset bottom rows:
#                    id  congress bill_type  bill_number bill_version  \
# 125236   118sres103is       118      sres          103           is
# 125237   118sres140is       118      sres          140           is
# 125238  118sres351ats       118      sres          351          ats
# 125239  118sres330ats       118      sres          330          ats
# 125240   118sres71ats       118      sres           71          ats
# 125241  118sres123ats       118      sres          123          ats
# 125242   118sres124is       118      sres          124           is
# 125243  118sres215ats       118      sres          215          ats
# 125244   118sres83ats       118      sres           83          ats
# 125245   118sres335is       118      sres          335           is
#
#                                                  sections  sections_length  \
# 125236  [{'text': 'That the Senate— (1) recognizes Gir...                1
# 125237  [{'text': 'That the Senate— (1) commemorates t...                1
# 125238  [{'text': 'That the Senate— (1) designates Sep...                1
# 125239  [{'text': 'That the Senate— (1) expresses supp...                1
# 125240  [{'text': 'That the Senate— (1) congratulates ...                1
# 125241  [{'text': 'That the Senate— (1) recognizes the...                1
# 125242  [{'text': 'That the Senate— (1) designates Mar...                1
# 125243  [{'text': 'That the Senate— (1) supports the r...                1
# 125244  [{'text': 'That the Senate— (1) designates the...                1
# 125245  [{'text': 'That the Senate— (1) designates Sep...                1
#
#                                                      text  text_length  \
# 125236  That the Senate— (1) recognizes Girl Scouts of...          465
# 125237  That the Senate— (1) commemorates the 200th an...          850
# 125238  That the Senate— (1) designates September 25, ...          191
# 125239  That the Senate— (1) expresses support for the...          750
# 125240  That the Senate— (1) congratulates the Kansas ...          533
# 125241  That the Senate— (1) recognizes the week of Ma...          693
# 125242  That the Senate— (1) designates March 24, 2023...         1809
# 125243  That the Senate— (1) supports the recognition ...          554
# 125244  That the Senate— (1) designates the week of Fe...          421
# 125245  That the Senate— (1) designates September 23, ...          460
#
#                                                   summary  summary_length  \
# 125236  This resolution (1) recognizes Girl Scouts of ...             286
# 125237  This resolution commemorates the 200th anniver...             437
# 125238  This resolution designates September 25, 2023,...             180
# 125239  This resolution expresses support for National...              76
# 125240  This resolution congratulates the Kansas City ...              90
# 125241  This resolution recognizes National Poison Pre...             143
# 125242  This resolution designates National Women of C...             143
# 125243  This resolution designates May 9, 2023, as Nat...             146
# 125244  This resolution designates February 6-February...              92
# 125245  This resolution designates September 23, 2023,...             209
#
#                                                     title
# 125236  A resolution recognizing Girl Scouts of the Un...
# 125237  A resolution commemorating 200 years of offici...
# 125238  A resolution designating September 25, 2023, a...
# 125239  A resolution expressing support for the goals ...
# 125240  A resolution congratulating the Kansas City Ch...
# 125241  A resolution recognizing the week of March 19 ...
# 125242  A resolution designating March 24th, 2023, as ...
# 125243  A resolution supporting the mission and goals ...
# 125244  A resolution designating the week of February ...
# 125245  A resolution designating September 23, 2023, t...

# %%
print('Dataset info:')
df.info()
# Out:
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125246 entries, 0 to 125245
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               125246 non-null  object
#  1   congress         125246 non-null  int64
#  2   bill_type        125246 non-null  object
#  3   bill_number      125246 non-null  int64
#  4   bill_version     125246 non-null  object
#  5   sections         125246 non-null  object
#  6   sections_length  125246 non-null  int64
#  7   text             125246 non-null  object
#  8   text_length      125246 non-null  int64
#  9   summary          125246 non-null  object
#  10  summary_length   125246 non-null  int64
#  11  title            125246 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 11.5+ MB

# %%
congresses = df['congress'].unique()
for congress in congresses:
    print(f'Congress: "{congress}" has "{len(df[df["congress"] == congress])}" dataset items.')
    bill_types = df[df['congress'] == congress]['bill_type'].unique()
    for bill_type in bill_types:
        print(f'    Bill type: "{bill_type}" has "{len(df[(df["congress"] == congress) & (df["bill_type"] == bill_type)])}" dataset items.')
        bill_versions = df[(df['congress'] == congress) & (df['bill_type'] == bill_type)]['bill_version'].unique()
        for bill_version in bill_versions:
            print(f'        Bill version: "{bill_version}" has "{len(df[(df["congress"] == congress) & (df["bill_type"] == bill_type) & (df["bill_version"] == bill_version)])}" dataset items.')
# Out:
# Congress: "108" has "1613" dataset items.
#     Bill type: "hconres" has "147" dataset items.
#         Bill version: "ih" has "147" dataset items.
#     Bill type: "hjres" has "11" dataset items.
#         Bill version: "ih" has "11" dataset items.
#     Bill type: "hr" has "1112" dataset items.
#         Bill version: "ih" has "1112" dataset items.
#     Bill type: "hres" has "245" dataset items.
#         Bill version: "ih" has "244" dataset items.
#         Bill version: "ath" has "1" dataset items.
#     Bill type: "s" has "55" dataset items.
#         Bill version: "is" has "52" dataset items.
#         Bill version: "ris" has "1" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#         Bill version: "cps" has "1" dataset items.
#     Bill type: "sconres" has "6" dataset items.
#         Bill version: "is" has "6" dataset items.
#     Bill type: "sres" has "37" dataset items.
#         Bill version: "ats" has "20" dataset items.
#         Bill version: "is" has "17" dataset items.
# Congress: "109" has "10763" dataset items.
#     Bill type: "hconres" has "435" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#         Bill version: "enr" has "9" dataset items.
#         Bill version: "ih" has "400" dataset items.
#         Bill version: "rds" has "8" dataset items.
#         Bill version: "rh" has "5" dataset items.
#         Bill version: "rfs" has "5" dataset items.
#         Bill version: "eh" has "3" dataset items.
#         Bill version: "ath" has "3" dataset items.
#         Bill version: "iph" has "1" dataset items.
#     Bill type: "hjres" has "78" dataset items.
#         Bill version: "ih" has "70" dataset items.
#         Bill version: "rh" has "4" dataset items.
#         Bill version: "rds" has "3" dataset items.
#         Bill version: "eh" has "1" dataset items.
#     Bill type: "hr" has "5756" dataset items.
#         Bill version: "ih" has "5407" dataset items.
#         Bill version: "rh" has "222" dataset items.
#         Bill version: "rfs" has "64" dataset items.
#         Bill version: "cph" has "12" dataset items.
#         Bill version: "rds" has "17" dataset items.
#         Bill version: "rs" has "20" dataset items.
#         Bill version: "eh" has "7" dataset items.
#         Bill version: "enr" has "5" dataset items.
#         Bill version: "ath" has "1" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#     Bill type: "hres" has "934" dataset items.
#         Bill version: "ih" has "612" dataset items.
#         Bill version: "eh" has "184" dataset items.
#         Bill version: "rh" has "133" dataset items.
#         Bill version: "lth" has "2" dataset items.
#         Bill version: "ath" has "3" dataset items.
#     Bill type: "s" has "2842" dataset items.
#         Bill version: "is" has "2510" dataset items.
#         Bill version: "rs" has "203" dataset items.
#         Bill version: "cps" has "36" dataset items.
#         Bill version: "pcs" has "88" dataset items.
#         Bill version: "rh" has "3" dataset items.
#         Bill version: "rfs" has "1" dataset items.
#         Bill version: "ris" has "1" dataset items.
#     Bill type: "sconres" has "99" dataset items.
#         Bill version: "is" has "81" dataset items.
#         Bill version: "ats" has "17" dataset items.
#         Bill version: "hds" has "1" dataset items.
#     Bill type: "sjres" has "33" dataset items.
#         Bill version: "is" has "30" dataset items.
#         Bill version: "cps" has "1" dataset items.
#         Bill version: "rs" has "2" dataset items.
#     Bill type: "sres" has "586" dataset items.
#         Bill version: "is" has "212" dataset items.
#         Bill version: "rs" has "9" dataset items.
#         Bill version: "ats" has "365" dataset items.
# Congress: "110" has "13721" dataset items.
#     Bill type: "hconres" has "436" dataset items.
#         Bill version: "ih" has "323" dataset items.
#         Bill version: "enr" has "59" dataset items.
#         Bill version: "rds" has "7" dataset items.
#         Bill version: "rfs" has "39" dataset items.
#         Bill version: "rs" has "2" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#         Bill version: "eh" has "2" dataset items.
#         Bill version: "rh" has "2" dataset items.
#     Bill type: "hjres" has "99" dataset items.
#         Bill version: "ih" has "92" dataset items.
#         Bill version: "eh" has "2" dataset items.
#         Bill version: "cph" has "1" dataset items.
#         Bill version: "rds" has "1" dataset items.
#         Bill version: "rs" has "1" dataset items.
#         Bill version: "rfs" has "1" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#     Bill type: "hr" has "7213" dataset items.
#         Bill version: "ih" has "6562" dataset items.
#         Bill version: "rfs" has "250" dataset items.
#         Bill version: "rs" has "50" dataset items.
#         Bill version: "rh" has "286" dataset items.
#         Bill version: "rds" has "12" dataset items.
#         Bill version: "rch" has "1" dataset items.
#         Bill version: "pcs" has "29" dataset items.
#         Bill version: "cph" has "11" dataset items.
#         Bill version: "rcs" has "1" dataset items.
#         Bill version: "eah" has "1" dataset items.
#         Bill version: "eh" has "9" dataset items.
#         Bill version: "cds" has "1" dataset items.
#     Bill type: "hres" has "1508" dataset items.
#         Bill version: "eh" has "812" dataset items.
#         Bill version: "ih" has "665" dataset items.
#         Bill version: "lth" has "9" dataset items.
#         Bill version: "rh" has "20" dataset items.
#         Bill version: "ath" has "2" dataset items.
#     Bill type: "s" has "3597" dataset items.
#         Bill version: "is" has "2931" dataset items.
#         Bill version: "rs" has "342" dataset items.
#         Bill version: "hds" has "2" dataset items.
#         Bill version: "eah" has "4" dataset items.
#         Bill version: "enr" has "29" dataset items.
#         Bill version: "pcs" has "156" dataset items.
#         Bill version: "rfh" has "76" dataset items.
#         Bill version: "cps" has "39" dataset items.
#         Bill version: "es" has "7" dataset items.
#         Bill version: "rcs" has "6" dataset items.
#         Bill version: "cds" has "4" dataset items.
#         Bill version: "ris" has "1" dataset items.
#     Bill type: "sconres" has "106" dataset items.
#         Bill version: "is" has "54" dataset items.
#         Bill version: "rfh" has "23" dataset items.
#         Bill version: "ats" has "14" dataset items.
#         Bill version: "rs" has "5" dataset items.
#         Bill version: "es" has "8" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#         Bill version: "eah" has "1" dataset items.
#     Bill type: "sjres" has "44" dataset items.
#         Bill version: "is" has "28" dataset items.
#         Bill version: "rs" has "6" dataset items.
#         Bill version: "rfh" has "4" dataset items.
#         Bill version: "pcs" has "4" dataset items.
#         Bill version: "enr" has "1" dataset items.
#         Bill version: "cps" has "1" dataset items.
#     Bill type: "sres" has "718" dataset items.
#         Bill version: "ats" has "516" dataset items.
#         Bill version: "is" has "172" dataset items.
#         Bill version: "rs" has "23" dataset items.
#         Bill version: "pcs" has "5" dataset items.
#         Bill version: "cds" has "1" dataset items.
#         Bill version: "hds" has "1" dataset items.
# Congress: "111" has "13521" dataset items.
#     Bill type: "hconres" has "336" dataset items.
#         Bill version: "enr" has "52" dataset items.
#         Bill version: "ih" has "273" dataset items.
#         Bill version: "rds" has "6" dataset items.
#         Bill version: "eh" has "4" dataset items.
#         Bill version: "cdh" has "1" dataset items.
#     Bill type: "hjres" has "107" dataset items.
#         Bill version: "ih" has "102" dataset items.
#         Bill version: "rds" has "3" dataset items.
#         Bill version: "rfs" has "1" dataset items.
#         Bill version: "eh" has "1" dataset items.
#     Bill type: "hr" has "6547" dataset items.
#         Bill version: "ih" has "6515" dataset items.
#         Bill version: "eh" has "10" dataset items.
#         Bill version: "pcs" has "12" dataset items.
#         Bill version: "rds" has "8" dataset items.
#         Bill version: "enr" has "1" dataset items.
#         Bill version: "rh" has "1" dataset items.
#     Bill type: "hres" has "1779" dataset items.
#         Bill version: "ih" has "1509" dataset items.
#         Bill version: "eh" has "245" dataset items.
#         Bill version: "rh" has "9" dataset items.
#         Bill version: "rds" has "1" dataset items.
#         Bill version: "lth" has "11" dataset items.
#         Bill version: "rth" has "4" dataset items.
#     Bill type: "s" has "3940" dataset items.
#         Bill version: "rs" has "222" dataset items.
#         Bill version: "is" has "3476" dataset items.
#         Bill version: "enr" has "38" dataset items.
#         Bill version: "rfh" has "55" dataset items.
#         Bill version: "pcs" has "106" dataset items.
#         Bill version: "cps" has "31" dataset items.
#         Bill version: "es" has "3" dataset items.
#         Bill version: "eah" has "1" dataset items.
#         Bill version: "rcs" has "8" dataset items.
#     Bill type: "sconres" has "77" dataset items.
#         Bill version: "ats" has "6" dataset items.
#         Bill version: "is" has "41" dataset items.
#         Bill version: "rfh" has "23" dataset items.
#         Bill version: "es" has "4" dataset items.
#         Bill version: "rs" has "1" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#     Bill type: "sjres" has "41" dataset items.
#         Bill version: "rs" has "3" dataset items.
#         Bill version: "is" has "21" dataset items.
#         Bill version: "cps" has "5" dataset items.
#         Bill version: "rfh" has "3" dataset items.
#         Bill version: "pcs" has "7" dataset items.
#         Bill version: "rcs" has "1" dataset items.
#         Bill version: "es" has "1" dataset items.
#     Bill type: "sres" has "694" dataset items.
#         Bill version: "ats" has "481" dataset items.
#         Bill version: "is" has "190" dataset items.
#         Bill version: "rs" has "21" dataset items.
#         Bill version: "pcs" has "2" dataset items.
# Congress: "112" has "12272" dataset items.
#     Bill type: "hconres" has "147" dataset items.
#         Bill version: "ih" has "114" dataset items.
#         Bill version: "enr" has "24" dataset items.
#         Bill version: "rds" has "7" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#     Bill type: "hjres" has "122" dataset items.
#         Bill version: "ih" has "119" dataset items.
#         Bill version: "rds" has "3" dataset items.
#     Bill type: "hr" has "6719" dataset items.
#         Bill version: "ih" has "6690" dataset items.
#         Bill version: "rh" has "7" dataset items.
#         Bill version: "eh" has "9" dataset items.
#         Bill version: "pcs" has "6" dataset items.
#         Bill version: "rds" has "7" dataset items.
#     Bill type: "hres" has "845" dataset items.
#         Bill version: "ih" has "652" dataset items.
#         Bill version: "eh" has "188" dataset items.
#         Bill version: "rh" has "3" dataset items.
#         Bill version: "lth" has "2" dataset items.
#     Bill type: "s" has "3695" dataset items.
#         Bill version: "is" has "3257" dataset items.
#         Bill version: "pcs" has "111" dataset items.
#         Bill version: "rs" has "208" dataset items.
#         Bill version: "enr" has "15" dataset items.
#         Bill version: "es" has "7" dataset items.
#         Bill version: "rfh" has "67" dataset items.
#         Bill version: "rcs" has "8" dataset items.
#         Bill version: "cps" has "21" dataset items.
#         Bill version: "eah" has "1" dataset items.
#     Bill type: "sconres" has "65" dataset items.
#         Bill version: "ats" has "17" dataset items.
#         Bill version: "is" has "23" dataset items.
#         Bill version: "pcs" has "10" dataset items.
#         Bill version: "rfh" has "14" dataset items.
#         Bill version: "enr" has "1" dataset items.
#     Bill type: "sjres" has "51" dataset items.
#         Bill version: "pcs" has "14" dataset items.
#         Bill version: "is" has "28" dataset items.
#         Bill version: "rfh" has "4" dataset items.
#         Bill version: "enr" has "1" dataset items.
#         Bill version: "rs" has "1" dataset items.
#         Bill version: "cps" has "1" dataset items.
#         Bill version: "cds" has "2" dataset items.
#     Bill type: "sres" has "628" dataset items.
#         Bill version: "ats" has "451" dataset items.
#         Bill version: "is" has "147" dataset items.
#         Bill version: "pcs" has "3" dataset items.
#         Bill version: "rs" has "24" dataset items.
#         Bill version: "lts" has "2" dataset items.
#         Bill version: "as" has "1" dataset items.
# Congress: "113" has "10627" dataset items.
#     Bill type: "hconres" has "125" dataset items.
#         Bill version: "ih" has "84" dataset items.
#         Bill version: "enr" has "32" dataset items.
#         Bill version: "eas" has "1" dataset items.
#         Bill version: "rds" has "6" dataset items.
#         Bill version: "rfs" has "1" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#     Bill type: "hjres" has "131" dataset items.
#         Bill version: "ih" has "119" dataset items.
#         Bill version: "rh" has "1" dataset items.
#         Bill version: "rds" has "3" dataset items.
#         Bill version: "fph" has "2" dataset items.
#         Bill version: "pcs" has "4" dataset items.
#         Bill version: "eah" has "1" dataset items.
#         Bill version: "eas" has "1" dataset items.
#     Bill type: "hr" has "5881" dataset items.
#         Bill version: "ih" has "5251" dataset items.
#         Bill version: "rh" has "199" dataset items.
#         Bill version: "rfs" has "296" dataset items.
#         Bill version: "rs" has "54" dataset items.
#         Bill version: "eas" has "24" dataset items.
#         Bill version: "pcs" has "18" dataset items.
#         Bill version: "rds" has "29" dataset items.
#         Bill version: "eah" has "8" dataset items.
#         Bill version: "rcs" has "1" dataset items.
#         Bill version: "pp" has "1" dataset items.
#     Bill type: "hres" has "782" dataset items.
#         Bill version: "ih" has "588" dataset items.
#         Bill version: "eh" has "189" dataset items.
#         Bill version: "rh" has "2" dataset items.
#         Bill version: "cdh" has "1" dataset items.
#         Bill version: "lth" has "2" dataset items.
#     Bill type: "s" has "3019" dataset items.
#         Bill version: "is" has "2557" dataset items.
#         Bill version: "rs" has "249" dataset items.
#         Bill version: "pcs" has "125" dataset items.
#         Bill version: "rfh" has "59" dataset items.
#         Bill version: "eah" has "7" dataset items.
#         Bill version: "rh" has "4" dataset items.
#         Bill version: "cps" has "11" dataset items.
#         Bill version: "rts" has "2" dataset items.
#         Bill version: "rcs" has "5" dataset items.
#     Bill type: "sconres" has "43" dataset items.
#         Bill version: "ats" has "7" dataset items.
#         Bill version: "is" has "22" dataset items.
#         Bill version: "enr" has "12" dataset items.
#         Bill version: "rs" has "1" dataset items.
#         Bill version: "eah" has "1" dataset items.
#     Bill type: "sjres" has "47" dataset items.
#         Bill version: "is" has "37" dataset items.
#         Bill version: "pcs" has "3" dataset items.
#         Bill version: "rs" has "2" dataset items.
#         Bill version: "rfh" has "5" dataset items.
#     Bill type: "sres" has "599" dataset items.
#         Bill version: "ats" has "412" dataset items.
#         Bill version: "is" has "173" dataset items.
#         Bill version: "rs" has "8" dataset items.
#         Bill version: "pcs" has "5" dataset items.
#         Bill version: "rts" has "1" dataset items.
# Congress: "114" has "12059" dataset items.
#     Bill type: "hconres" has "183" dataset items.
#         Bill version: "ih" has "128" dataset items.
#         Bill version: "enr" has "40" dataset items.
#         Bill version: "rfs" has "8" dataset items.
#         Bill version: "rds" has "5" dataset items.
#         Bill version: "rh" has "2" dataset items.
#     Bill type: "hjres" has "108" dataset items.
#         Bill version: "ih" has "101" dataset items.
#         Bill version: "rds" has "2" dataset items.
#         Bill version: "rh" has "4" dataset items.
#         Bill version: "rfs" has "1" dataset items.
#     Bill type: "hr" has "6522" dataset items.
#         Bill version: "ih" has "5749" dataset items.
#         Bill version: "rfs" has "443" dataset items.
#         Bill version: "rs" has "62" dataset items.
#         Bill version: "rh" has "195" dataset items.
#         Bill version: "eah" has "10" dataset items.
#         Bill version: "eas" has "46" dataset items.
#         Bill version: "rds" has "10" dataset items.
#         Bill version: "pap" has "1" dataset items.
#         Bill version: "pcs" has "6" dataset items.
#     Bill type: "hres" has "957" dataset items.
#         Bill version: "eh" has "220" dataset items.
#         Bill version: "ih" has "734" dataset items.
#         Bill version: "rth" has "2" dataset items.
#         Bill version: "rh" has "1" dataset items.
#     Bill type: "s" has "3548" dataset items.
#         Bill version: "is" has "3011" dataset items.
#         Bill version: "rs" has "337" dataset items.
#         Bill version: "rfh" has "55" dataset items.
#         Bill version: "pcs" has "103" dataset items.
#         Bill version: "cps" has "9" dataset items.
#         Bill version: "eah" has "24" dataset items.
#         Bill version: "rcs" has "2" dataset items.
#         Bill version: "rh" has "5" dataset items.
#         Bill version: "rts" has "1" dataset items.
#         Bill version: "eas" has "1" dataset items.
#     Bill type: "sconres" has "58" dataset items.
#         Bill version: "ats" has "3" dataset items.
#         Bill version: "is" has "33" dataset items.
#         Bill version: "enr" has "11" dataset items.
#         Bill version: "rs" has "5" dataset items.
#         Bill version: "rfh" has "6" dataset items.
#     Bill type: "sjres" has "41" dataset items.
#         Bill version: "is" has "33" dataset items.
#         Bill version: "pcs" has "8" dataset items.
#     Bill type: "sres" has "642" dataset items.
#         Bill version: "ats" has "431" dataset items.
#         Bill version: "is" has "194" dataset items.
#         Bill version: "pcs" has "4" dataset items.
#         Bill version: "rs" has "12" dataset items.
#         Bill version: "hds" has "1" dataset items.
# Congress: "115" has "13546" dataset items.
#     Bill type: "hconres" has "149" dataset items.
#         Bill version: "ih" has "114" dataset items.
#         Bill version: "enr" has "22" dataset items.
#         Bill version: "rfs" has "8" dataset items.
#         Bill version: "rds" has "3" dataset items.
#         Bill version: "eas" has "1" dataset items.
#         Bill version: "rh" has "1" dataset items.
#     Bill type: "hjres" has "146" dataset items.
#         Bill version: "ih" has "136" dataset items.
#         Bill version: "rfs" has "3" dataset items.
#         Bill version: "rds" has "7" dataset items.
#     Bill type: "hr" has "7384" dataset items.
#         Bill version: "ih" has "6477" dataset items.
#         Bill version: "rfs" has "591" dataset items.
#         Bill version: "rs" has "118" dataset items.
#         Bill version: "eas" has "64" dataset items.
#         Bill version: "rh" has "97" dataset items.
#         Bill version: "rds" has "22" dataset items.
#         Bill version: "rcs" has "2" dataset items.
#         Bill version: "eah" has "7" dataset items.
#         Bill version: "pap" has "1" dataset items.
#         Bill version: "pcs" has "4" dataset items.
#         Bill version: "eh" has "1" dataset items.
#     Bill type: "hres" has "1187" dataset items.
#         Bill version: "eh" has "269" dataset items.
#         Bill version: "ih" has "900" dataset items.
#         Bill version: "lth" has "5" dataset items.
#         Bill version: "rh" has "13" dataset items.
#     Bill type: "s" has "3805" dataset items.
#         Bill version: "is" has "3288" dataset items.
#         Bill version: "rs" has "382" dataset items.
#         Bill version: "rfh" has "39" dataset items.
#         Bill version: "pcs" has "48" dataset items.
#         Bill version: "eah" has "28" dataset items.
#         Bill version: "cps" has "13" dataset items.
#         Bill version: "rcs" has "4" dataset items.
#         Bill version: "eas" has "2" dataset items.
#         Bill version: "es" has "1" dataset items.
#     Bill type: "sconres" has "59" dataset items.
#         Bill version: "enr" has "17" dataset items.
#         Bill version: "is" has "32" dataset items.
#         Bill version: "pcs" has "3" dataset items.
#         Bill version: "ats" has "6" dataset items.
#         Bill version: "rs" has "1" dataset items.
#     Bill type: "sjres" has "69" dataset items.
#         Bill version: "pcs" has "9" dataset items.
#         Bill version: "is" has "53" dataset items.
#         Bill version: "cps" has "2" dataset items.
#         Bill version: "rs" has "1" dataset items.
#         Bill version: "rfh" has "4" dataset items.
#     Bill type: "sres" has "747" dataset items.
#         Bill version: "ats" has "448" dataset items.
#         Bill version: "is" has "285" dataset items.
#         Bill version: "rs" has "13" dataset items.
#         Bill version: "pcs" has "1" dataset items.
# Congress: "116" has "16599" dataset items.
#     Bill type: "hconres" has "128" dataset items.
#         Bill version: "ih" has "101" dataset items.
#         Bill version: "enr" has "20" dataset items.
#         Bill version: "rds" has "3" dataset items.
#         Bill version: "rfs" has "2" dataset items.
#         Bill version: "rh" has "2" dataset items.
#     Bill type: "hjres" has "110" dataset items.
#         Bill version: "ih" has "101" dataset items.
#         Bill version: "eas" has "2" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#         Bill version: "rds" has "4" dataset items.
#         Bill version: "rfs" has "1" dataset items.
#     Bill type: "hr" has "9061" dataset items.
#         Bill version: "rfs" has "378" dataset items.
#         Bill version: "ih" has "8302" dataset items.
#         Bill version: "rh" has "265" dataset items.
#         Bill version: "eas" has "29" dataset items.
#         Bill version: "pcs" has "17" dataset items.
#         Bill version: "rs" has "45" dataset items.
#         Bill version: "rds" has "17" dataset items.
#         Bill version: "eah" has "8" dataset items.
#     Bill type: "hres" has "1273" dataset items.
#         Bill version: "ih" has "1037" dataset items.
#         Bill version: "eh" has "228" dataset items.
#         Bill version: "lth" has "5" dataset items.
#         Bill version: "rds" has "2" dataset items.
#         Bill version: "rh" has "1" dataset items.
#     Bill type: "s" has "5085" dataset items.
#         Bill version: "is" has "4597" dataset items.
#         Bill version: "rs" has "381" dataset items.
#         Bill version: "cps" has "32" dataset items.
#         Bill version: "pcs" has "38" dataset items.
#         Bill version: "eah" has "22" dataset items.
#         Bill version: "rcs" has "5" dataset items.
#         Bill version: "rfh" has "8" dataset items.
#         Bill version: "ips" has "1" dataset items.
#         Bill version: "enr" has "1" dataset items.
#     Bill type: "sconres" has "52" dataset items.
#         Bill version: "rfh" has "3" dataset items.
#         Bill version: "is" has "33" dataset items.
#         Bill version: "rs" has "3" dataset items.
#         Bill version: "enr" has "9" dataset items.
#         Bill version: "ats" has "4" dataset items.
#     Bill type: "sjres" has "82" dataset items.
#         Bill version: "is" has "68" dataset items.
#         Bill version: "cps" has "3" dataset items.
#         Bill version: "pcs" has "8" dataset items.
#         Bill version: "es" has "2" dataset items.
#         Bill version: "rs" has "1" dataset items.
#     Bill type: "sres" has "808" dataset items.
#         Bill version: "ats" has "452" dataset items.
#         Bill version: "is" has "350" dataset items.
#         Bill version: "rs" has "6" dataset items.
# Congress: "117" has "15824" dataset items.
#     Bill type: "hconres" has "113" dataset items.
#         Bill version: "ih" has "98" dataset items.
#         Bill version: "enr" has "10" dataset items.
#         Bill version: "rds" has "4" dataset items.
#         Bill version: "rfs" has "1" dataset items.
#     Bill type: "hjres" has "100" dataset items.
#         Bill version: "ih" has "97" dataset items.
#         Bill version: "rfs" has "1" dataset items.
#         Bill version: "rh" has "1" dataset items.
#         Bill version: "rds" has "1" dataset items.
#     Bill type: "hr" has "8562" dataset items.
#         Bill version: "ih" has "7804" dataset items.
#         Bill version: "rh" has "272" dataset items.
#         Bill version: "eas" has "29" dataset items.
#         Bill version: "rs" has "63" dataset items.
#         Bill version: "rds" has "87" dataset items.
#         Bill version: "rfs" has "286" dataset items.
#         Bill version: "pcs" has "13" dataset items.
#         Bill version: "eah" has "5" dataset items.
#         Bill version: "rcs" has "1" dataset items.
#         Bill version: "cph" has "2" dataset items.
#     Bill type: "hres" has "1410" dataset items.
#         Bill version: "ih" has "1173" dataset items.
#         Bill version: "eh" has "193" dataset items.
#         Bill version: "rh" has "40" dataset items.
#         Bill version: "lth" has "2" dataset items.
#         Bill version: "rds" has "2" dataset items.
#     Bill type: "s" has "4706" dataset items.
#         Bill version: "is" has "4231" dataset items.
#         Bill version: "rs" has "363" dataset items.
#         Bill version: "pcs" has "64" dataset items.
#         Bill version: "eah" has "13" dataset items.
#         Bill version: "cps" has "27" dataset items.
#         Bill version: "rh" has "2" dataset items.
#         Bill version: "rcs" has "2" dataset items.
#         Bill version: "rfh" has "1" dataset items.
#         Bill version: "eas" has "3" dataset items.
#     Bill type: "sconres" has "44" dataset items.
#         Bill version: "is" has "25" dataset items.
#         Bill version: "ats" has "5" dataset items.
#         Bill version: "enr" has "9" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#         Bill version: "rs" has "3" dataset items.
#     Bill type: "sjres" has "66" dataset items.
#         Bill version: "pcs" has "13" dataset items.
#         Bill version: "is" has "51" dataset items.
#         Bill version: "rs" has "2" dataset items.
#     Bill type: "sres" has "823" dataset items.
#         Bill version: "is" has "307" dataset items.
#         Bill version: "ats" has "501" dataset items.
#         Bill version: "rs" has "12" dataset items.
#         Bill version: "es" has "2" dataset items.
#         Bill version: "pcs" has "1" dataset items.
# Congress: "118" has "4701" dataset items.
#     Bill type: "hconres" has "40" dataset items.
#         Bill version: "ih" has "29" dataset items.
#         Bill version: "rfs" has "4" dataset items.
#         Bill version: "enr" has "5" dataset items.
#         Bill version: "rh" has "1" dataset items.
#         Bill version: "eh" has "1" dataset items.
#     Bill type: "hjres" has "65" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#         Bill version: "ih" has "52" dataset items.
#         Bill version: "rds" has "3" dataset items.
#         Bill version: "rfs" has "4" dataset items.
#         Bill version: "rh" has "4" dataset items.
#     Bill type: "hr" has "2696" dataset items.
#         Bill version: "ih" has "2511" dataset items.
#         Bill version: "rfs" has "71" dataset items.
#         Bill version: "rh" has "92" dataset items.
#         Bill version: "eas" has "3" dataset items.
#         Bill version: "pcs" has "16" dataset items.
#         Bill version: "rds" has "2" dataset items.
#         Bill version: "cph" has "1" dataset items.
#     Bill type: "hres" has "460" dataset items.
#         Bill version: "eh" has "64" dataset items.
#         Bill version: "ih" has "388" dataset items.
#         Bill version: "rh" has "7" dataset items.
#         Bill version: "rch" has "1" dataset items.
#     Bill type: "s" has "1187" dataset items.
#         Bill version: "is" has "1059" dataset items.
#         Bill version: "rs" has "110" dataset items.
#         Bill version: "rfh" has "1" dataset items.
#         Bill version: "pcs" has "12" dataset items.
#         Bill version: "cps" has "4" dataset items.
#         Bill version: "pap" has "1" dataset items.
#     Bill type: "sconres" has "9" dataset items.
#         Bill version: "rs" has "1" dataset items.
#         Bill version: "is" has "8" dataset items.
#     Bill type: "sjres" has "25" dataset items.
#         Bill version: "is" has "20" dataset items.
#         Bill version: "pcs" has "5" dataset items.
#     Bill type: "sres" has "219" dataset items.
#         Bill version: "is" has "95" dataset items.
#         Bill version: "ats" has "120" dataset items.
#         Bill version: "rs" has "4" dataset items.

# %%
print('Dataset row with max text length:')
df[df['text_length']==df['text_length'].max()]
# Out:
# Dataset row with max text length:
#                 id  congress bill_type  bill_number bill_version  \
# 91337  116hr133eah       116        hr          133          eah
#
#                                                 sections  sections_length  \
# 91337  [{'text': 'That the House agree to the amendme...             2271
#
#                                                     text  text_length  \
# 91337  That the House agree to the amendment of the S...      5599885
#
#                                                  summary  summary_length  \
# 91337  Consolidated Appropriations Act, 2021\n\nDIVIS...           72899
#
#                                                    title
# 91337  Making consolidated appropriations for the fis...

# %%
print('Dataset row with max sections length:')
df[df['sections_length']==df['sections_length'].max()]
# Out:
# Dataset row with max sections length:
#                 id  congress bill_type  bill_number bill_version  \
# 91337  116hr133eah       116        hr          133          eah
#
#                                                 sections  sections_length  \
# 91337  [{'text': 'That the House agree to the amendme...             2271
#
#                                                     text  text_length  \
# 91337  That the House agree to the amendment of the S...      5599885
#
#                                                  summary  summary_length  \
# 91337  Consolidated Appropriations Act, 2021\n\nDIVIS...           72899
#
#                                                    title
# 91337  Making consolidated appropriations for the fis...

# %%
print('Dataset row with max summary length:')
df[df['summary_length']==df['summary_length'].max()]
# Out:
# Dataset row with max summary length:
#                    id  congress bill_type  bill_number bill_version  \
# 107259  117hr2617eas2       117        hr         2617          eas
#
#                                                  sections  sections_length  \
# 107259  [{'text': 'That the bill from the House of Rep...             1970
#
#                                                      text  text_length  \
# 107259  That the bill from the House of Representative...      3764945
#
#                                                   summary  summary_length  \
# 107259  Consolidated Appropriations Act, 2023\n\nThis ...          613809
#
#                                                     title
# 107259  To amend section 1115 of title 31, United Stat...
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
