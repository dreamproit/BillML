# %%
import pandas as pd
import json

from common.constants.billml import BillMLConstants

# edit this to change the dataset file
DATASET_FILE_NAME = 'bill_text_us_11-10-2023_13-02-35.jsonl'

DATASET_PATH = (
    f'{BillMLConstants.BILLML_DATASETS_STORAGE_FILEPATH.value}/'
    f'{BillMLConstants.BILLML_BILL_TEXT_US_DATASET_NAME.value}/'
    f'{DATASET_FILE_NAME}'
)
chunks = pd.read_json(path_or_buf=DATASET_PATH, lines=True, chunksize=10000)
dfs = []
for chunk in chunks:
  # Note due to the large size of the dataset, we have to exclude massive text and sections columns.
  dfs.append(chunk.loc[:, ~chunk.columns.isin(['text', 'sections'])])

df = pd.concat(dfs)

# %%
print('Dataset top rows:')
df.head(10)
# Out:
# Dataset top rows:
#                 id  congress bill_type  bill_number bill_version  \
# 0  107hconres470ih       107   hconres          470           ih
# 1  107hconres502ih       107   hconres          502           ih
# 2  107hconres467ih       107   hconres          467           ih
# 3  107hconres501ih       107   hconres          501           ih
# 4  107hconres497ih       107   hconres          497           ih
# 5  107hconres517ih       107   hconres          517           ih
# 6  107hconres491ih       107   hconres          491           ih
# 7  107hconres518ih       107   hconres          518           ih
# 8  107hconres515ih       107   hconres          515           ih
# 9  107hconres472ih       107   hconres          472           ih
#
#                                                title  sections_length  \
# 0  Supporting the goals and ideals of College Sav...                1
# 1  Expressing the sense of the Congress in suppor...                1
# 2  Expressing the sense of Congress that Lionel H...                1
# 3  Expressing the sense of Congress that Congress...                1
# 4  Supporting the goals and ideas of National Tak...                1
# 5  Condemning the Democratic People’s Republic of...                1
# 6  Supporting the goals and ideals of National Sa...                1
# 7  Expressing the sense of Congress that the depl...                1
# 8  Expressing the sense of Congress with respect ...                1
# 9  Recognizing the 100th anniversary of the 4-H Y...                1
#
#    text_length
# 0           69
# 1          747
# 2          171
# 3          186
# 4          479
# 5         1954
# 6           92
# 7          447
# 8         1162
# 9          352

# %%
print('Dataset bottom rows:')
df.tail(10)
# Out:
# Dataset bottom rows:
#                    id  congress bill_type  bill_number bill_version  \
# 166769   118sres71ats       118      sres           71          ats
# 166770  118sres123ats       118      sres          123          ats
# 166771   118sres123is       118      sres          123           is
# 166772  118sres277ats       118      sres          277          ats
# 166773   118sres124is       118      sres          124           is
# 166774  118sres215ats       118      sres          215          ats
# 166775   118sres371is       118      sres          371           is
# 166776   118sres83ats       118      sres           83          ats
# 166777  118sres369ats       118      sres          369          ats
# 166778   118sres335is       118      sres          335           is
#
#                                                     title  sections_length  \
# 166769  Congratulating the Kansas City Chiefs on their...                1
# 166770  Recognizing the week of March 19 through March...                1
# 166771  Recognizing the week of March 19 through March...                1
# 166772  Expressing the condolences of the Senate and h...                1
# 166773  Designating March 24th, 2023, as National Wome...                1
# 166774  Supporting the mission and goals of National F...                1
# 166775  Supporting the designation of the week of Sept...                1
# 166776  Designating the week of February 6 through 10,...                1
# 166777   Expressing support for the designation of Sep...                1
# 166778  Designating September 23, 2023, through Octobe...                1
#
#         text_length
# 166769          533
# 166770          693
# 166771          693
# 166772          841
# 166773         1809
# 166774          554
# 166775         1717
# 166776          421
# 166777          490
# 166778          460

# %%
print('Dataset info:')
df.info()
# Out:
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166779 entries, 0 to 166778
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               166779 non-null  object
#  1   congress         166779 non-null  int64
#  2   bill_type        166779 non-null  object
#  3   bill_number      166779 non-null  int64
#  4   bill_version     166779 non-null  object
#  5   title            166101 non-null  object
#  6   sections_length  166779 non-null  int64
#  7   text_length      166779 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 10.2+ MB

# %%
congresses = df['congress'].unique()
for congress in congresses:
    print(f'Congress: "{congress}" has "{len(df[df["congress"] == congress])}" dataset items.')
    bill_types = df[df['congress'] == congress]['bill_type'].unique()
    for bill_type in bill_types:
        print(f'    Bill type: "{bill_type}" has "{len(df[(df["congress"] == congress) & (df["bill_type"] == bill_type)])}" dataset items.')
        bill_versions = df[(df['congress'] == congress) & (df['bill_type'] == bill_type)]['bill_version'].unique()
        for bill_version in bill_versions:
            print(f'        Bill version: "{bill_version}" has "{len(df[(df["congress"] == congress) & (df["bill_type"] == bill_type) & (df["bill_version"] == bill_version)])}" dataset items.')
# Out:
# Congress: "107" has "246" dataset items.
#     Bill type: "hconres" has "12" dataset items.
#         Bill version: "ih" has "12" dataset items.
#     Bill type: "hjres" has "1" dataset items.
#         Bill version: "ih" has "1" dataset items.
#     Bill type: "hr" has "75" dataset items.
#         Bill version: "ih" has "75" dataset items.
#     Bill type: "hres" has "158" dataset items.
#         Bill version: "eh" has "96" dataset items.
#         Bill version: "ih" has "50" dataset items.
#         Bill version: "ath" has "12" dataset items.
# Congress: "108" has "1924" dataset items.
#     Bill type: "hconres" has "148" dataset items.
#         Bill version: "ih" has "148" dataset items.
#     Bill type: "hjres" has "11" dataset items.
#         Bill version: "ih" has "11" dataset items.
#     Bill type: "hr" has "1419" dataset items.
#         Bill version: "ih" has "1414" dataset items.
#         Bill version: "rh" has "5" dataset items.
#     Bill type: "hres" has "248" dataset items.
#         Bill version: "ih" has "246" dataset items.
#         Bill version: "rh" has "1" dataset items.
#         Bill version: "ath" has "1" dataset items.
#     Bill type: "s" has "55" dataset items.
#         Bill version: "is" has "52" dataset items.
#         Bill version: "ris" has "1" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#         Bill version: "cps" has "1" dataset items.
#     Bill type: "sconres" has "6" dataset items.
#         Bill version: "is" has "6" dataset items.
#     Bill type: "sres" has "37" dataset items.
#         Bill version: "ats" has "20" dataset items.
#         Bill version: "is" has "17" dataset items.
# Congress: "109" has "12080" dataset items.
#     Bill type: "hconres" has "510" dataset items.
#         Bill version: "ih" has "422" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#         Bill version: "eh" has "50" dataset items.
#         Bill version: "enr" has "10" dataset items.
#         Bill version: "rds" has "10" dataset items.
#         Bill version: "rh" has "8" dataset items.
#         Bill version: "rfs" has "5" dataset items.
#         Bill version: "ath" has "3" dataset items.
#         Bill version: "iph" has "1" dataset items.
#     Bill type: "hjres" has "93" dataset items.
#         Bill version: "ih" has "76" dataset items.
#         Bill version: "rh" has "4" dataset items.
#         Bill version: "rds" has "4" dataset items.
#         Bill version: "eh" has "6" dataset items.
#         Bill version: "enr" has "3" dataset items.
#     Bill type: "hr" has "6526" dataset items.
#         Bill version: "ih" has "5716" dataset items.
#         Bill version: "rh" has "285" dataset items.
#         Bill version: "eh" has "276" dataset items.
#         Bill version: "rfs" has "66" dataset items.
#         Bill version: "enr" has "113" dataset items.
#         Bill version: "cph" has "12" dataset items.
#         Bill version: "rds" has "36" dataset items.
#         Bill version: "rs" has "20" dataset items.
#         Bill version: "ath" has "1" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#     Bill type: "hres" has "1133" dataset items.
#         Bill version: "ih" has "738" dataset items.
#         Bill version: "eh" has "184" dataset items.
#         Bill version: "rh" has "205" dataset items.
#         Bill version: "ath" has "4" dataset items.
#         Bill version: "lth" has "2" dataset items.
#     Bill type: "s" has "3044" dataset items.
#         Bill version: "is" has "2703" dataset items.
#         Bill version: "rs" has "208" dataset items.
#         Bill version: "cps" has "36" dataset items.
#         Bill version: "pcs" has "88" dataset items.
#         Bill version: "rh" has "3" dataset items.
#         Bill version: "es" has "4" dataset items.
#         Bill version: "rfs" has "1" dataset items.
#         Bill version: "ris" has "1" dataset items.
#     Bill type: "sconres" has "99" dataset items.
#         Bill version: "is" has "81" dataset items.
#         Bill version: "ats" has "17" dataset items.
#         Bill version: "hds" has "1" dataset items.
#     Bill type: "sjres" has "34" dataset items.
#         Bill version: "is" has "31" dataset items.
#         Bill version: "cps" has "1" dataset items.
#         Bill version: "rs" has "2" dataset items.
#     Bill type: "sres" has "641" dataset items.
#         Bill version: "is" has "265" dataset items.
#         Bill version: "rs" has "10" dataset items.
#         Bill version: "ats" has "366" dataset items.
# Congress: "110" has "18358" dataset items.
#     Bill type: "hconres" has "760" dataset items.
#         Bill version: "ih" has "411" dataset items.
#         Bill version: "eh" has "186" dataset items.
#         Bill version: "enr" has "66" dataset items.
#         Bill version: "rds" has "23" dataset items.
#         Bill version: "rh" has "11" dataset items.
#         Bill version: "rfs" has "53" dataset items.
#         Bill version: "rs" has "5" dataset items.
#         Bill version: "pcs" has "3" dataset items.
#         Bill version: "eas" has "1" dataset items.
#         Bill version: "ath" has "1" dataset items.
#     Bill type: "hjres" has "128" dataset items.
#         Bill version: "ih" has "95" dataset items.
#         Bill version: "eh" has "13" dataset items.
#         Bill version: "enr" has "10" dataset items.
#         Bill version: "cph" has "2" dataset items.
#         Bill version: "eas" has "1" dataset items.
#         Bill version: "rds" has "3" dataset items.
#         Bill version: "rs" has "1" dataset items.
#         Bill version: "rfs" has "2" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#     Bill type: "hr" has "9541" dataset items.
#         Bill version: "ih" has "7179" dataset items.
#         Bill version: "eh" has "918" dataset items.
#         Bill version: "rfs" has "333" dataset items.
#         Bill version: "rs" has "58" dataset items.
#         Bill version: "rh" has "578" dataset items.
#         Bill version: "enr" has "285" dataset items.
#         Bill version: "pcs" has "68" dataset items.
#         Bill version: "rds" has "58" dataset items.
#         Bill version: "rch" has "2" dataset items.
#         Bill version: "eas" has "38" dataset items.
#         Bill version: "eah" has "9" dataset items.
#         Bill version: "cph" has "12" dataset items.
#         Bill version: "rcs" has "1" dataset items.
#         Bill version: "ris" has "1" dataset items.
#         Bill version: "cds" has "1" dataset items.
#     Bill type: "hres" has "2260" dataset items.
#         Bill version: "ih" has "1185" dataset items.
#         Bill version: "eh" has "812" dataset items.
#         Bill version: "rh" has "242" dataset items.
#         Bill version: "ath" has "12" dataset items.
#         Bill version: "lth" has "9" dataset items.
#     Bill type: "s" has "4459" dataset items.
#         Bill version: "is" has "3403" dataset items.
#         Bill version: "rs" has "431" dataset items.
#         Bill version: "hds" has "2" dataset items.
#         Bill version: "eah" has "22" dataset items.
#         Bill version: "es" has "177" dataset items.
#         Bill version: "enr" has "109" dataset items.
#         Bill version: "pcs" has "156" dataset items.
#         Bill version: "rfh" has "97" dataset items.
#         Bill version: "cps" has "39" dataset items.
#         Bill version: "rcs" has "7" dataset items.
#         Bill version: "ris" has "6" dataset items.
#         Bill version: "cds" has "4" dataset items.
#         Bill version: "rh" has "6" dataset items.
#     Bill type: "sconres" has "184" dataset items.
#         Bill version: "is" has "77" dataset items.
#         Bill version: "rfh" has "23" dataset items.
#         Bill version: "ats" has "27" dataset items.
#         Bill version: "enr" has "7" dataset items.
#         Bill version: "es" has "39" dataset items.
#         Bill version: "rs" has "7" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#         Bill version: "eah" has "2" dataset items.
#     Bill type: "sjres" has "68" dataset items.
#         Bill version: "is" has "38" dataset items.
#         Bill version: "rs" has "7" dataset items.
#         Bill version: "es" has "7" dataset items.
#         Bill version: "rfh" has "4" dataset items.
#         Bill version: "enr" has "6" dataset items.
#         Bill version: "rh" has "1" dataset items.
#         Bill version: "pcs" has "4" dataset items.
#         Bill version: "cps" has "1" dataset items.
#     Bill type: "sres" has "958" dataset items.
#         Bill version: "ats" has "522" dataset items.
#         Bill version: "is" has "344" dataset items.
#         Bill version: "rs" has "84" dataset items.
#         Bill version: "pcs" has "5" dataset items.
#         Bill version: "cds" has "1" dataset items.
#         Bill version: "rcs" has "1" dataset items.
#         Bill version: "hds" has "1" dataset items.
# Congress: "111" has "17896" dataset items.
#     Bill type: "hconres" has "622" dataset items.
#         Bill version: "ih" has "308" dataset items.
#         Bill version: "rds" has "46" dataset items.
#         Bill version: "eh" has "119" dataset items.
#         Bill version: "enr" has "62" dataset items.
#         Bill version: "rfs" has "70" dataset items.
#         Bill version: "ats" has "2" dataset items.
#         Bill version: "rh" has "11" dataset items.
#         Bill version: "rs" has "1" dataset items.
#         Bill version: "cdh" has "1" dataset items.
#         Bill version: "eas" has "2" dataset items.
#     Bill type: "hjres" has "148" dataset items.
#         Bill version: "ih" has "103" dataset items.
#         Bill version: "rds" has "8" dataset items.
#         Bill version: "eh" has "16" dataset items.
#         Bill version: "enr" has "12" dataset items.
#         Bill version: "rfs" has "7" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#         Bill version: "eas" has "1" dataset items.
#     Bill type: "hr" has "8844" dataset items.
#         Bill version: "ih" has "6515" dataset items.
#         Bill version: "eh" has "710" dataset items.
#         Bill version: "enr" has "238" dataset items.
#         Bill version: "rs" has "144" dataset items.
#         Bill version: "rfs" has "568" dataset items.
#         Bill version: "pcs" has "76" dataset items.
#         Bill version: "rh" has "420" dataset items.
#         Bill version: "eas" has "80" dataset items.
#         Bill version: "rds" has "65" dataset items.
#         Bill version: "eah" has "13" dataset items.
#         Bill version: "pp" has "10" dataset items.
#         Bill version: "rcs" has "3" dataset items.
#         Bill version: "cps" has "1" dataset items.
#         Bill version: "as" has "1" dataset items.
#     Bill type: "hres" has "2632" dataset items.
#         Bill version: "ih" has "1509" dataset items.
#         Bill version: "eh" has "887" dataset items.
#         Bill version: "rh" has "215" dataset items.
#         Bill version: "rth" has "6" dataset items.
#         Bill version: "rds" has "1" dataset items.
#         Bill version: "lth" has "11" dataset items.
#         Bill version: "ath" has "2" dataset items.
#         Bill version: "rch" has "1" dataset items.
#     Bill type: "s" has "4577" dataset items.
#         Bill version: "rs" has "293" dataset items.
#         Bill version: "is" has "3796" dataset items.
#         Bill version: "enr" has "100" dataset items.
#         Bill version: "es" has "152" dataset items.
#         Bill version: "rfh" has "72" dataset items.
#         Bill version: "pcs" has "106" dataset items.
#         Bill version: "eah" has "14" dataset items.
#         Bill version: "cps" has "31" dataset items.
#         Bill version: "rcs" has "9" dataset items.
#         Bill version: "rh" has "2" dataset items.
#         Bill version: "as" has "1" dataset items.
#         Bill version: "eas" has "1" dataset items.
#     Bill type: "sconres" has "154" dataset items.
#         Bill version: "ats" has "19" dataset items.
#         Bill version: "is" has "55" dataset items.
#         Bill version: "rfh" has "23" dataset items.
#         Bill version: "enr" has "15" dataset items.
#         Bill version: "es" has "33" dataset items.
#         Bill version: "rs" has "4" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#         Bill version: "eah" has "2" dataset items.
#         Bill version: "hds" has "1" dataset items.
#     Bill type: "sjres" has "71" dataset items.
#         Bill version: "rs" has "4" dataset items.
#         Bill version: "is" has "33" dataset items.
#         Bill version: "cps" has "5" dataset items.
#         Bill version: "enr" has "7" dataset items.
#         Bill version: "es" has "9" dataset items.
#         Bill version: "rfh" has "5" dataset items.
#         Bill version: "pcs" has "7" dataset items.
#         Bill version: "rcs" has "1" dataset items.
#     Bill type: "sres" has "848" dataset items.
#         Bill version: "ats" has "482" dataset items.
#         Bill version: "is" has "323" dataset items.
#         Bill version: "rs" has "41" dataset items.
#         Bill version: "pcs" has "2" dataset items.
# Congress: "112" has "15108" dataset items.
#     Bill type: "hconres" has "244" dataset items.
#         Bill version: "ih" has "128" dataset items.
#         Bill version: "eh" has "41" dataset items.
#         Bill version: "rh" has "4" dataset items.
#         Bill version: "rfs" has "4" dataset items.
#         Bill version: "rds" has "35" dataset items.
#         Bill version: "enr" has "30" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#     Bill type: "hjres" has "154" dataset items.
#         Bill version: "ih" has "119" dataset items.
#         Bill version: "rds" has "5" dataset items.
#         Bill version: "eh" has "11" dataset items.
#         Bill version: "cph" has "2" dataset items.
#         Bill version: "enr" has "6" dataset items.
#         Bill version: "rh" has "4" dataset items.
#         Bill version: "pcs" has "6" dataset items.
#         Bill version: "eas" has "1" dataset items.
#     Bill type: "hr" has "8446" dataset items.
#         Bill version: "ih" has "6690" dataset items.
#         Bill version: "eh" has "484" dataset items.
#         Bill version: "rh" has "466" dataset items.
#         Bill version: "rfs" has "312" dataset items.
#         Bill version: "rds" has "98" dataset items.
#         Bill version: "enr" has "198" dataset items.
#         Bill version: "pcs" has "79" dataset items.
#         Bill version: "eas" has "51" dataset items.
#         Bill version: "pp" has "5" dataset items.
#         Bill version: "rcs" has "4" dataset items.
#         Bill version: "rs" has "53" dataset items.
#         Bill version: "rhuc" has "1" dataset items.
#         Bill version: "rch" has "1" dataset items.
#         Bill version: "eah" has "4" dataset items.
#     Bill type: "hres" has "1008" dataset items.
#         Bill version: "ih" has "652" dataset items.
#         Bill version: "eh" has "218" dataset items.
#         Bill version: "rh" has "136" dataset items.
#         Bill version: "lth" has "2" dataset items.
#     Bill type: "s" has "4285" dataset items.
#         Bill version: "is" has "3551" dataset items.
#         Bill version: "pcs" has "111" dataset items.
#         Bill version: "rs" has "264" dataset items.
#         Bill version: "enr" has "73" dataset items.
#         Bill version: "eah" has "12" dataset items.
#         Bill version: "es" has "146" dataset items.
#         Bill version: "rfh" has "79" dataset items.
#         Bill version: "rcs" has "9" dataset items.
#         Bill version: "cps" has "21" dataset items.
#         Bill version: "rh" has "16" dataset items.
#         Bill version: "eas" has "1" dataset items.
#         Bill version: "rts" has "1" dataset items.
#         Bill version: "pp" has "1" dataset items.
#     Bill type: "sconres" has "135" dataset items.
#         Bill version: "ats" has "25" dataset items.
#         Bill version: "enr" has "20" dataset items.
#         Bill version: "es" has "32" dataset items.
#         Bill version: "is" has "31" dataset items.
#         Bill version: "pcs" has "10" dataset items.
#         Bill version: "rfh" has "14" dataset items.
#         Bill version: "rs" has "3" dataset items.
#     Bill type: "sjres" has "79" dataset items.
#         Bill version: "pcs" has "14" dataset items.
#         Bill version: "is" has "40" dataset items.
#         Bill version: "rfh" has "6" dataset items.
#         Bill version: "enr" has "6" dataset items.
#         Bill version: "es" has "7" dataset items.
#         Bill version: "eah" has "1" dataset items.
#         Bill version: "rs" has "2" dataset items.
#         Bill version: "cps" has "1" dataset items.
#         Bill version: "cds" has "2" dataset items.
#     Bill type: "sres" has "757" dataset items.
#         Bill version: "ats" has "454" dataset items.
#         Bill version: "is" has "252" dataset items.
#         Bill version: "pcs" has "3" dataset items.
#         Bill version: "rs" has "44" dataset items.
#         Bill version: "lts" has "2" dataset items.
#         Bill version: "as" has "1" dataset items.
#         Bill version: "es" has "1" dataset items.
# Congress: "113" has "13756" dataset items.
#     Bill type: "hconres" has "233" dataset items.
#         Bill version: "ih" has "103" dataset items.
#         Bill version: "rds" has "37" dataset items.
#         Bill version: "eh" has "41" dataset items.
#         Bill version: "enr" has "36" dataset items.
#         Bill version: "rh" has "8" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#         Bill version: "eas" has "3" dataset items.
#         Bill version: "rs" has "1" dataset items.
#         Bill version: "rfs" has "2" dataset items.
#     Bill type: "hjres" has "190" dataset items.
#         Bill version: "ih" has "124" dataset items.
#         Bill version: "rds" has "7" dataset items.
#         Bill version: "eh" has "23" dataset items.
#         Bill version: "enr" has "10" dataset items.
#         Bill version: "rh" has "2" dataset items.
#         Bill version: "pcs" has "16" dataset items.
#         Bill version: "fph" has "3" dataset items.
#         Bill version: "eah" has "2" dataset items.
#         Bill version: "eas" has "2" dataset items.
#         Bill version: "pp" has "1" dataset items.
#     Bill type: "hr" has "7832" dataset items.
#         Bill version: "ih" has "5854" dataset items.
#         Bill version: "rh" has "514" dataset items.
#         Bill version: "eh" has "575" dataset items.
#         Bill version: "enr" has "207" dataset items.
#         Bill version: "rfs" has "389" dataset items.
#         Bill version: "rs" has "61" dataset items.
#         Bill version: "pcs" has "72" dataset items.
#         Bill version: "rds" has "117" dataset items.
#         Bill version: "eas" has "33" dataset items.
#         Bill version: "eah" has "8" dataset items.
#         Bill version: "rcs" has "1" dataset items.
#         Bill version: "pp" has "1" dataset items.
#     Bill type: "hres" has "932" dataset items.
#         Bill version: "ih" has "623" dataset items.
#         Bill version: "eh" has "189" dataset items.
#         Bill version: "rh" has "117" dataset items.
#         Bill version: "cdh" has "1" dataset items.
#         Bill version: "lth" has "2" dataset items.
#     Bill type: "s" has "3649" dataset items.
#         Bill version: "is" has "2879" dataset items.
#         Bill version: "rs" has "305" dataset items.
#         Bill version: "pcs" has "129" dataset items.
#         Bill version: "enr" has "73" dataset items.
#         Bill version: "es" has "153" dataset items.
#         Bill version: "rfh" has "72" dataset items.
#         Bill version: "eah" has "7" dataset items.
#         Bill version: "rh" has "11" dataset items.
#         Bill version: "cps" has "12" dataset items.
#         Bill version: "rts" has "2" dataset items.
#         Bill version: "rcs" has "6" dataset items.
#     Bill type: "sconres" has "90" dataset items.
#         Bill version: "ats" has "18" dataset items.
#         Bill version: "es" has "22" dataset items.
#         Bill version: "is" has "25" dataset items.
#         Bill version: "rfh" has "4" dataset items.
#         Bill version: "enr" has "18" dataset items.
#         Bill version: "rs" has "1" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#         Bill version: "eah" has "1" dataset items.
#     Bill type: "sjres" has "66" dataset items.
#         Bill version: "is" has "44" dataset items.
#         Bill version: "pcs" has "3" dataset items.
#         Bill version: "rfh" has "6" dataset items.
#         Bill version: "enr" has "4" dataset items.
#         Bill version: "es" has "6" dataset items.
#         Bill version: "rs" has "3" dataset items.
#     Bill type: "sres" has "764" dataset items.
#         Bill version: "ats" has "418" dataset items.
#         Bill version: "is" has "287" dataset items.
#         Bill version: "rs" has "50" dataset items.
#         Bill version: "es" has "1" dataset items.
#         Bill version: "pcs" has "7" dataset items.
#         Bill version: "rts" has "1" dataset items.
# Congress: "114" has "16080" dataset items.
#     Bill type: "hconres" has "321" dataset items.
#         Bill version: "ih" has "157" dataset items.
#         Bill version: "rds" has "46" dataset items.
#         Bill version: "eh" has "55" dataset items.
#         Bill version: "enr" has "41" dataset items.
#         Bill version: "rfs" has "9" dataset items.
#         Bill version: "rh" has "8" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#         Bill version: "eas" has "3" dataset items.
#         Bill version: "rs" has "1" dataset items.
#     Bill type: "hjres" has "127" dataset items.
#         Bill version: "ih" has "106" dataset items.
#         Bill version: "rds" has "3" dataset items.
#         Bill version: "eh" has "6" dataset items.
#         Bill version: "enr" has "4" dataset items.
#         Bill version: "rh" has "5" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#         Bill version: "rfs" has "1" dataset items.
#     Bill type: "hr" has "9131" dataset items.
#         Bill version: "ih" has "6492" dataset items.
#         Bill version: "rds" has "185" dataset items.
#         Bill version: "eh" has "768" dataset items.
#         Bill version: "rh" has "684" dataset items.
#         Bill version: "rfs" has "553" dataset items.
#         Bill version: "enr" has "219" dataset items.
#         Bill version: "rs" has "85" dataset items.
#         Bill version: "eas" has "60" dataset items.
#         Bill version: "eah" has "12" dataset items.
#         Bill version: "pcs" has "68" dataset items.
#         Bill version: "pp" has "3" dataset items.
#         Bill version: "pap" has "1" dataset items.
#         Bill version: "rcs" has "1" dataset items.
#     Bill type: "hres" has "1130" dataset items.
#         Bill version: "eh" has "220" dataset items.
#         Bill version: "rh" has "134" dataset items.
#         Bill version: "ih" has "774" dataset items.
#         Bill version: "rth" has "2" dataset items.
#     Bill type: "s" has "4412" dataset items.
#         Bill version: "is" has "3425" dataset items.
#         Bill version: "rs" has "396" dataset items.
#         Bill version: "es" has "195" dataset items.
#         Bill version: "rfh" has "108" dataset items.
#         Bill version: "pcs" has "111" dataset items.
#         Bill version: "cps" has "15" dataset items.
#         Bill version: "enr" has "111" dataset items.
#         Bill version: "rh" has "19" dataset items.
#         Bill version: "rcs" has "3" dataset items.
#         Bill version: "eah" has "25" dataset items.
#         Bill version: "pap" has "1" dataset items.
#         Bill version: "cds" has "1" dataset items.
#         Bill version: "rts" has "1" dataset items.
#         Bill version: "eas" has "1" dataset items.
#     Bill type: "sconres" has "111" dataset items.
#         Bill version: "ats" has "13" dataset items.
#         Bill version: "enr" has "13" dataset items.
#         Bill version: "es" has "24" dataset items.
#         Bill version: "is" has "43" dataset items.
#         Bill version: "rs" has "6" dataset items.
#         Bill version: "rfh" has "9" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#         Bill version: "eah" has "1" dataset items.
#     Bill type: "sjres" has "57" dataset items.
#         Bill version: "is" has "40" dataset items.
#         Bill version: "pcs" has "8" dataset items.
#         Bill version: "es" has "5" dataset items.
#         Bill version: "enr" has "4" dataset items.
#     Bill type: "sres" has "791" dataset items.
#         Bill version: "ats" has "434" dataset items.
#         Bill version: "is" has "309" dataset items.
#         Bill version: "rs" has "43" dataset items.
#         Bill version: "pcs" has "4" dataset items.
#         Bill version: "hds" has "1" dataset items.
# Congress: "115" has "18498" dataset items.
#     Bill type: "hconres" has "233" dataset items.
#         Bill version: "ih" has "134" dataset items.
#         Bill version: "eh" has "34" dataset items.
#         Bill version: "enr" has "22" dataset items.
#         Bill version: "rfs" has "9" dataset items.
#         Bill version: "rds" has "24" dataset items.
#         Bill version: "rh" has "6" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#         Bill version: "eas" has "3" dataset items.
#     Bill type: "hjres" has "210" dataset items.
#         Bill version: "ih" has "146" dataset items.
#         Bill version: "rds" has "19" dataset items.
#         Bill version: "eh" has "21" dataset items.
#         Bill version: "enr" has "18" dataset items.
#         Bill version: "rfs" has "3" dataset items.
#         Bill version: "rh" has "2" dataset items.
#         Bill version: "pcs" has "1" dataset items.
#     Bill type: "hr" has "10728" dataset items.
#         Bill version: "ih" has "7350" dataset items.
#         Bill version: "rds" has "123" dataset items.
#         Bill version: "eh" has "990" dataset items.
#         Bill version: "enr" has "284" dataset items.
#         Bill version: "rh" has "870" dataset items.
#         Bill version: "rfs" has "810" dataset items.
#         Bill version: "rs" has "142" dataset items.
#         Bill version: "eas" has "77" dataset items.
#         Bill version: "pcs" has "67" dataset items.
#         Bill version: "rcs" has "2" dataset items.
#         Bill version: "pap" has "2" dataset items.
#         Bill version: "eah" has "11" dataset items.
#     Bill type: "hres" has "1410" dataset items.
#         Bill version: "eh" has "269" dataset items.
#         Bill version: "rh" has "166" dataset items.
#         Bill version: "ih" has "970" dataset items.
#         Bill version: "lth" has "5" dataset items.
#     Bill type: "s" has "4806" dataset items.
#         Bill version: "is" has "3742" dataset items.
#         Bill version: "rs" has "434" dataset items.
#         Bill version: "rfh" has "127" dataset items.
#         Bill version: "enr" has "133" dataset items.
#         Bill version: "es" has "259" dataset items.
#         Bill version: "pcs" has "48" dataset items.
#         Bill version: "eah" has "30" dataset items.
#         Bill version: "cps" has "14" dataset items.
#         Bill version: "rh" has "13" dataset items.
#         Bill version: "rcs" has "4" dataset items.
#         Bill version: "eas" has "2" dataset items.
#     Bill type: "sconres" has "106" dataset items.
#         Bill version: "ats" has "22" dataset items.
#         Bill version: "enr" has "19" dataset items.
#         Bill version: "es" has "24" dataset items.
#         Bill version: "is" has "33" dataset items.
#         Bill version: "pcs" has "4" dataset items.
#         Bill version: "rfh" has "3" dataset items.
#         Bill version: "rs" has "1" dataset items.
#     Bill type: "sjres" has "106" dataset items.
#         Bill version: "pcs" has "9" dataset items.
#         Bill version: "is" has "64" dataset items.
#         Bill version: "cps" has "3" dataset items.
#         Bill version: "es" has "15" dataset items.
#         Bill version: "rs" has "1" dataset items.
#         Bill version: "rfh" has "6" dataset items.
#         Bill version: "enr" has "8" dataset items.
#     Bill type: "sres" has "899" dataset items.
#         Bill version: "ats" has "449" dataset items.
#         Bill version: "is" has "420" dataset items.
#         Bill version: "rs" has "29" dataset items.
#         Bill version: "pcs" has "1" dataset items.
# Congress: "116" has "20446" dataset items.
#     Bill type: "hconres" has "190" dataset items.
#         Bill version: "ih" has "113" dataset items.
#         Bill version: "rds" has "24" dataset items.
#         Bill version: "eh" has "26" dataset items.
#         Bill version: "enr" has "21" dataset items.
#         Bill version: "rfs" has "2" dataset items.
#         Bill version: "rh" has "4" dataset items.
#     Bill type: "hjres" has "152" dataset items.
#         Bill version: "ih" has "106" dataset items.
#         Bill version: "pcs" has "3" dataset items.
#         Bill version: "eh" has "16" dataset items.
#         Bill version: "rh" has "2" dataset items.
#         Bill version: "rfs" has "4" dataset items.
#         Bill version: "rds" has "9" dataset items.
#         Bill version: "enr" has "10" dataset items.
#         Bill version: "eas" has "2" dataset items.
#     Bill type: "hr" has "11475" dataset items.
#         Bill version: "ih" has "9030" dataset items.
#         Bill version: "eh" has "777" dataset items.
#         Bill version: "rh" has "570" dataset items.
#         Bill version: "rfs" has "592" dataset items.
#         Bill version: "pcs" has "78" dataset items.
#         Bill version: "enr" has "214" dataset items.
#         Bill version: "eas" has "38" dataset items.
#         Bill version: "rds" has "110" dataset items.
#         Bill version: "rs" has "58" dataset items.
#         Bill version: "eah" has "8" dataset items.
#     Bill type: "hres" has "1447" dataset items.
#         Bill version: "ih" has "1124" dataset items.
#         Bill version: "eh" has "229" dataset items.
#         Bill version: "rh" has "87" dataset items.
#         Bill version: "lth" has "5" dataset items.
#         Bill version: "rds" has "2" dataset items.
#     Bill type: "s" has "5977" dataset items.
#         Bill version: "is" has "4994" dataset items.
#         Bill version: "es" has "262" dataset items.
#         Bill version: "rs" has "411" dataset items.
#         Bill version: "cps" has "34" dataset items.
#         Bill version: "enr" has "120" dataset items.
#         Bill version: "pcs" has "39" dataset items.
#         Bill version: "rfh" has "85" dataset items.
#         Bill version: "eah" has "22" dataset items.
#         Bill version: "rh" has "3" dataset items.
#         Bill version: "rcs" has "6" dataset items.
#         Bill version: "ips" has "1" dataset items.
#     Bill type: "sconres" has "99" dataset items.
#         Bill version: "rfh" has "10" dataset items.
#         Bill version: "ats" has "16" dataset items.
#         Bill version: "es" has "20" dataset items.
#         Bill version: "is" has "38" dataset items.
#         Bill version: "rs" has "4" dataset items.
#         Bill version: "enr" has "10" dataset items.
#         Bill version: "eah" has "1" dataset items.
#     Bill type: "sjres" has "130" dataset items.
#         Bill version: "is" has "75" dataset items.
#         Bill version: "enr" has "9" dataset items.
#         Bill version: "es" has "30" dataset items.
#         Bill version: "cps" has "3" dataset items.
#         Bill version: "rfh" has "3" dataset items.
#         Bill version: "pcs" has "9" dataset items.
#         Bill version: "rs" has "1" dataset items.
#     Bill type: "sres" has "976" dataset items.
#         Bill version: "ats" has "454" dataset items.
#         Bill version: "is" has "480" dataset items.
#         Bill version: "rs" has "42" dataset items.
# Congress: "117" has "21401" dataset items.
#     Bill type: "hconres" has "176" dataset items.
#         Bill version: "ih" has "116" dataset items.
#         Bill version: "rds" has "17" dataset items.
#         Bill version: "eh" has "23" dataset items.
#         Bill version: "enr" has "14" dataset items.
#         Bill version: "rfs" has "4" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#     Bill type: "hjres" has "118" dataset items.
#         Bill version: "ih" has "106" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#         Bill version: "eh" has "4" dataset items.
#         Bill version: "enr" has "3" dataset items.
#         Bill version: "rfs" has "1" dataset items.
#         Bill version: "rh" has "1" dataset items.
#         Bill version: "rds" has "1" dataset items.
#     Bill type: "hr" has "11908" dataset items.
#         Bill version: "ih" has "9657" dataset items.
#         Bill version: "eh" has "713" dataset items.
#         Bill version: "rfs" has "540" dataset items.
#         Bill version: "rh" has "493" dataset items.
#         Bill version: "rds" has "130" dataset items.
#         Bill version: "enr" has "198" dataset items.
#         Bill version: "eas" has "35" dataset items.
#         Bill version: "rs" has "77" dataset items.
#         Bill version: "pcs" has "55" dataset items.
#         Bill version: "rhuc" has "1" dataset items.
#         Bill version: "eah" has "6" dataset items.
#         Bill version: "rcs" has "1" dataset items.
#         Bill version: "cph" has "2" dataset items.
#     Bill type: "hres" has "1730" dataset items.
#         Bill version: "ih" has "1375" dataset items.
#         Bill version: "eh" has "203" dataset items.
#         Bill version: "rh" has "144" dataset items.
#         Bill version: "lth" has "2" dataset items.
#         Bill version: "rds" has "2" dataset items.
#         Bill version: "ath" has "4" dataset items.
#     Bill type: "s" has "6216" dataset items.
#         Bill version: "is" has "5246" dataset items.
#         Bill version: "enr" has "160" dataset items.
#         Bill version: "es" has "272" dataset items.
#         Bill version: "rs" has "406" dataset items.
#         Bill version: "pcs" has "69" dataset items.
#         Bill version: "eah" has "16" dataset items.
#         Bill version: "cps" has "30" dataset items.
#         Bill version: "rfh" has "6" dataset items.
#         Bill version: "rh" has "3" dataset items.
#         Bill version: "rts" has "1" dataset items.
#         Bill version: "rcs" has "3" dataset items.
#         Bill version: "eas" has "3" dataset items.
#         Bill version: "fps" has "1" dataset items.
#     Bill type: "sconres" has "89" dataset items.
#         Bill version: "is" has "32" dataset items.
#         Bill version: "rs" has "4" dataset items.
#         Bill version: "ats" has "15" dataset items.
#         Bill version: "enr" has "14" dataset items.
#         Bill version: "es" has "19" dataset items.
#         Bill version: "pcs" has "5" dataset items.
#     Bill type: "sjres" has "99" dataset items.
#         Bill version: "pcs" has "14" dataset items.
#         Bill version: "es" has "11" dataset items.
#         Bill version: "is" has "68" dataset items.
#         Bill version: "rs" has "2" dataset items.
#         Bill version: "enr" has "4" dataset items.
#     Bill type: "sres" has "1065" dataset items.
#         Bill version: "is" has "484" dataset items.
#         Bill version: "ats" has "528" dataset items.
#         Bill version: "rs" has "50" dataset items.
#         Bill version: "es" has "2" dataset items.
#         Bill version: "pcs" has "1" dataset items.
# Congress: "118" has "10986" dataset items.
#     Bill type: "hconres" has "99" dataset items.
#         Bill version: "ih" has "68" dataset items.
#         Bill version: "eh" has "11" dataset items.
#         Bill version: "rfs" has "5" dataset items.
#         Bill version: "rds" has "5" dataset items.
#         Bill version: "enr" has "6" dataset items.
#         Bill version: "rh" has "4" dataset items.
#     Bill type: "hjres" has "133" dataset items.
#         Bill version: "ih" has "93" dataset items.
#         Bill version: "pcs" has "2" dataset items.
#         Bill version: "eh" has "12" dataset items.
#         Bill version: "enr" has "7" dataset items.
#         Bill version: "rfs" has "7" dataset items.
#         Bill version: "rds" has "4" dataset items.
#         Bill version: "rh" has "8" dataset items.
#     Bill type: "hr" has "6222" dataset items.
#         Bill version: "ih" has "5771" dataset items.
#         Bill version: "rh" has "188" dataset items.
#         Bill version: "eh" has "131" dataset items.
#         Bill version: "rfs" has "92" dataset items.
#         Bill version: "rds" has "8" dataset items.
#         Bill version: "eas" has "3" dataset items.
#         Bill version: "pcs" has "19" dataset items.
#         Bill version: "enr" has "9" dataset items.
#         Bill version: "cph" has "1" dataset items.
#     Bill type: "hres" has "807" dataset items.
#         Bill version: "eh" has "74" dataset items.
#         Bill version: "ih" has "698" dataset items.
#         Bill version: "rh" has "34" dataset items.
#         Bill version: "rch" has "1" dataset items.
#     Bill type: "s" has "3195" dataset items.
#         Bill version: "is" has "2948" dataset items.
#         Bill version: "rs" has "170" dataset items.
#         Bill version: "es" has "46" dataset items.
#         Bill version: "enr" has "8" dataset items.
#         Bill version: "cps" has "7" dataset items.
#         Bill version: "rfh" has "1" dataset items.
#         Bill version: "pcs" has "14" dataset items.
#         Bill version: "pap" has "1" dataset items.
#     Bill type: "sconres" has "23" dataset items.
#         Bill version: "is" has "21" dataset items.
#         Bill version: "rs" has "2" dataset items.
#     Bill type: "sjres" has "58" dataset items.
#         Bill version: "is" has "45" dataset items.
#         Bill version: "enr" has "3" dataset items.
#         Bill version: "es" has "5" dataset items.
#         Bill version: "pcs" has "5" dataset items.
#     Bill type: "sres" has "449" dataset items.
#         Bill version: "is" has "233" dataset items.
#         Bill version: "ats" has "202" dataset items.
#         Bill version: "rs" has "13" dataset items.
#         Bill version: "hds" has "1" dataset items.

# %%
print('Dataset row with max text length:')
df[df['text_length']==df['text_length'].max()]
# Out:
# Dataset row with max text length:
#                  id  congress bill_type  bill_number bill_version title  \
# 118134  116hr133eah       116        hr          133          eah  None
#
#         sections_length  text_length
# 118134             2271      5599885

# %%
print('Dataset row with max sections length:')
df[df['sections_length']==df['sections_length'].max()]
# Out:
# Dataset row with max sections length:
#                  id  congress bill_type  bill_number bill_version title  \
# 118134  116hr133eah       116        hr          133          eah  None
#
#         sections_length  text_length
# 118134             2271      5599885
